# %%
import pandas as pd
from label_pool import LabelPool
from label_mapping import LabelMapping

# %%
uni = LabelPool.load('label_hubs/uni.csv')
datasets = ['coco', 'object365', 'openimages', 'oid600']
lms = {}
for dname in datasets:
    lms[dname] = LabelMapping.load(f'label_hubs/{dname}.csv')
for d in lms.values():
    uni.add_label_mapping(d)
uni.to_csv('complete_uni.csv')

# %%
cuni = LabelPool.load('complete_uni.csv')

# %%
cuni
# Out:
# LabelPool(uni2name={0: 'accordion', 1: 'adhesive tape', 2: 'air conditioner', 3: 'airplane', 4: 'alarm clock', 5: 'alpaca', 6: 'ambulance', 7: 'american football', 8: 'ant', 9: 'antelope', 10: 'apple', 11: 'arm', 12: 'artichoke', 13: 'avocado', 14: 'awning', 15: 'backpack', 16: 'bagel', 17: 'ball', 18: 'balloon', 19: 'banana', 20: 'banner', 21: 'baozi', 22: 'bar soap', 23: 'barbell', 24: 'barge', 25: 'barrel', 26: 'baseball', 27: 'baseball bat', 28: 'baseball glove', 29: 'basket', 30: 'basketball', 31: 'bat', 32: 'bathroom cabinet', 33: 'bathtub', 34: 'beaker', 35: 'bear', 36: 'beard', 37: 'bed', 38: 'bee', 39: 'beehive', 40: 'beer', 41: 'bell pepper', 42: 'belt', 43: 'bench', 44: 'bicycle', 45: 'bicycle helmet', 46: 'bicycle wheel', 47: 'bicyclist', 48: 'bidet', 49: 'bike rack', 50: 'billboard', 51: 'billiard ball', 52: 'billiard table', 53: 'binoculars', 54: 'bird', 55: 'blender', 56: 'blue jay', 57: 'board eraser', 58: 'boat', 59: 'book', 60: 'bookcase', 61: 'boot', 62: 'bottle', 63: 'bow and arrow', 64: 'bow tie', 65: 'bowl', 66: 'box', 67: 'boy', 68: 'bracelet', 69: 'brassiere', 70: 'bread', 71: 'briefcase', 72: 'broccoli', 73: 'bronze sculpture', 74: 'broom', 75: 'brown bear', 76: 'brush', 77: 'bull', 78: 'burrito', 79: 'bus', 80: 'bust', 81: 'butterfly', 82: 'cabbage', 83: 'cabinetry', 84: 'cake', 85: 'cake stand', 86: 'calculator', 87: 'camel', 88: 'camera', 89: 'canary', 90: 'candle', 91: 'candy', 92: 'cannon', 93: 'canoe', 94: 'cantaloupe', 95: 'car', 96: 'caravan', 97: 'carrot', 98: 'cart', 99: 'castle', 100: 'cat', 101: 'catch basin', 102: 'caterpillar', 103: 'cattle', 104: 'ceiling fan', 105: 'cello', 106: 'centipede', 107: 'chainsaw', 108: 'chair', 109: 'cheese', 110: 'cheetah', 111: 'cherry', 112: 'chest of drawers', 113: 'chicken', 114: 'chopstick', 115: 'christmas tree', 116: 'cleaning products', 117: 'clock', 118: 'coat', 119: 'cocktail', 120: 'coconut', 121: 'coffee', 122: 'coffee cup', 123: 'coffee table', 124: 'coffeemaker', 125: 'coin', 126: 'comb', 127: 'compact disc', 128: 'computer keyboard', 129: 'computer monitor', 130: 'computer mouse', 131: 'construction vehicle', 132: 'convenience store', 133: 'cookie', 134: 'corded phone', 135: 'corn', 136: 'cosmetic', 137: 'cosmetics mirror', 138: 'couch', 139: 'countertop', 140: 'cow', 141: 'cowboy hat', 142: 'crab', 143: 'crane', 144: 'cricket ball', 145: 'crocodile', 146: 'croissant', 147: 'crosswalk sign', 148: 'crown', 149: 'crutch', 150: 'cucumber', 151: 'cue', 152: 'cup', 153: 'cupboard', 154: 'curling stone', 155: 'curtain', 156: 'cutting board', 157: 'cymbal', 158: 'dagger', 159: 'deer', 160: 'desk', 161: 'desktop computer', 162: 'dessert', 163: 'dice', 164: 'digital clock', 165: 'dining table', 166: 'dinosaur', 167: 'dishwasher', 168: 'dog', 169: 'dog bed', 170: 'doll', 171: 'dolphin', 172: 'donkey', 173: 'donut', 174: 'door', 175: 'door handle', 176: 'dragonfly', 177: 'drawer', 178: 'dress', 179: 'drinking straw', 180: 'drum', 181: 'duck', 182: 'dumbbell', 183: 'dumpling', 184: 'durian', 185: 'eagle', 186: 'ear', 187: 'earbud', 188: 'earring', 189: 'egg', 190: 'eggplant', 191: 'electric drill', 192: 'electric fan', 193: 'elephant', 194: 'envelope', 195: 'eraser', 196: 'exhaust hood', 197: 'extension cord', 198: 'eye', 199: 'eyeglasses', 200: 'eyeliner pencil', 201: 'face', 202: 'falcon', 203: 'fedora', 204: 'fig', 205: 'filing cabinet', 206: 'fire extinguisher', 207: 'fire hydrant', 208: 'fire truck', 209: 'fireplace', 210: 'fish', 211: 'fishing rod', 212: 'flag', 213: 'flashlight', 214: 'flask', 215: 'flower', 216: 'flowerpot', 217: 'flute', 218: 'folder', 219: 'food processor', 220: 'foot', 221: 'football helmet', 222: 'fork', 223: 'fountain', 224: 'fox', 225: 'french fries', 226: 'french horn', 227: 'frisbee', 228: 'frog', 229: 'frying pan', 230: 'game board', 231: 'garden asparagus', 232: 'garlic', 233: 'gas stove', 234: 'giraffe', 235: 'girl', 236: 'globe', 237: 'glove', 238: 'goat', 239: 'goggles', 240: 'goldfish', 241: 'golf ball', 242: 'golf c ...

# %%
v3 = pd.read_csv('label_hubs/v3.csv')
uni = v3[['uni.label', 'uni.name']]
uni = uni.dropna().drop_duplicates()
uni = uni.rename(columns={'uni.label':'label', 'uni.name':'name'})
uni = uni.sort_values(by='label')
uni.to_csv('label_hubs/uni.csv', index=False)

# %%
uni
# Out:
#      label             name
# 0        0        accordion
# 1        1    adhesive tape
# 2        2  air conditioner
# 3        3         airplane
# 4        4      alarm clock
# ..     ...              ...
# 781    773           isopod
# 782    774         scorpion
# 783    775          grinder
# 784    776        submarine
# 785    777       hand dryer
#
# [778 rows x 2 columns]

# %%
# convert lp of each datasets
v3 = pd.read_csv('label_hubs/v3.csv')
datasets = ['coco', 'object365', 'openimages', 'oid600']
for dname in datasets:
    lname, nname = f'{dname}.label', f'{dname}.name'
    sel_df = v3[[lname, nname]].dropna().drop_duplicates()
    sel_df = v3.iloc[sel_df.index][[lname, nname, 'uni.label']]
    sel_df = sel_df.rename(columns={lname: 'label', nname:'name', 'uni.label':'uni'})
    sel_df = sel_df.sort_values(by=['label'])
    sel_df.to_csv(f'label_hubs/{dname}.csv', index=False, float_format='%.f')

# %%
# Out:
#      label           name  uni
# 0    585.0      Accordion    0
# 1    245.0  Adhesive tape    1
# 3    466.0       Airplane    3
# 4    276.0    Alarm clock    4
# 5    591.0         Alpaca    5
# ..     ...            ...  ...
# 781  220.0         Isopod  773
# 782  372.0       Scorpion  774
# 783  534.0        Grinder  775
# 784  371.0      Submarine  776
# 785  451.0     Hand dryer  777
#
# [600 rows x 3 columns]
